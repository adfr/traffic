# %%
import cv2
import numpy as np
import os
import sys
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from traffic import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data= "./gtsrb"

    # Get image arrays and labels for all image files
images, labels = load_data(data)

    # Split data into training and testing sets
labels = tf.keras.utils.to_categorical(labels)
x_train, x_test, y_train, y_test = train_test_split(
        np.array(images), np.array(labels), test_size=TEST_SIZE
    )

    # Get a compiled neural network
model = get_model()

    # Fit model on training data
print(x_train.shape)
print(y_train.shape)
model.fit(x_train, y_train, epochs=EPOCHS)

    # Evaluate neural network performance
# Out:
# ./gtsrb
# extracting directory  0
# extracting directory  1
# extracting directory  2
# extracting directory  3
# extracting directory  4
# extracting directory  5
# extracting directory  6
# extracting directory  7
# extracting directory  8
# extracting directory  9
# extracting directory  10
# extracting directory  11
# extracting directory  12
# extracting directory  13
# extracting directory  14
# extracting directory  15
# extracting directory  16
# extracting directory  17
# extracting directory  18
# extracting directory  19
# extracting directory  20
# extracting directory  21
# extracting directory  22
# extracting directory  23
# extracting directory  24
# extracting directory  25
# extracting directory  26
# extracting directory  27
# extracting directory  28
# extracting directory  29
# extracting directory  30
# extracting directory  31
# extracting directory  32
# extracting directory  33
# extracting directory  34
# extracting directory  35
# extracting directory  36
# extracting directory  37
# extracting directory  38
# extracting directory  39
# extracting directory  40
# extracting directory  41
# extracting directory  42
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 28, 28, 6)         168
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 12, 12, 16)        880
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 16)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 16)          2320
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                8224
# _________________________________________________________________
# dense_7 (Dense)              (None, 43)                1419
# =================================================================
# Total params: 13,011
# Trainable params: 13,011
# Non-trainable params: 0
# _________________________________________________________________
# (15984, 30, 30, 3)
# (15984, 43)
# Train on 15984 samples
# Epoch 1/30
# 15984/15984 [==============================] - 6s 364us/sample - loss: 3.1787 - accuracy: 0.2627
# Epoch 2/30
# 15984/15984 [==============================] - 5s 342us/sample - loss: 1.2937 - accuracy: 0.6423
# Epoch 3/30
# 15984/15984 [==============================] - 4s 267us/sample - loss: 0.8236 - accuracy: 0.7680
# Epoch 4/30
# 15984/15984 [==============================] - 4s 254us/sample - loss: 0.6005 - accuracy: 0.8338
# Epoch 5/30
# 15984/15984 [==============================] - 4s 255us/sample - loss: 0.4603 - accuracy: 0.8701
# Epoch 6/30
# 15984/15984 [==============================] - 4s 254us/sample - loss: 0.3879 - accuracy: 0.8915
# Epoch 7/30
# 15984/15984 [==============================] - 4s 254us/sample - loss: 0.3192 - accuracy: 0.9098
# Epoch 8/30
# 15984/15984 [==============================] - 4s 254us/sample - loss: 0.2866 - accuracy: 0.9173
# Epoch 9/30
# 15984/15984 [==============================] - 4s 254us/sample - loss: 0.2481 - accuracy: 0.9261
# Epoch 10/30
# 15984/15984 [==============================] - 4s 255us/sample - loss: 0.2174 - accuracy: 0.9362
# Epoch 11/30
# 15984/15984 [==============================] - 4s 253us/sample - loss: 0.1909 - accuracy: 0.9463
# Epoch 12/30
# 15984/15984 [==============================] - 4s 253us/sample - loss: 0.1717 - accuracy: 0.9477
# Epoch 13/30
# 15984/15984 [==============================] - 4s 253us/sample - loss: 0.1769 - accuracy: 0.9490
# Epoch 14/30
# 15984/15984 [==============================] - 4s 254us/sample - loss: 0.1374 - accuracy: 0.9582
# Epoch 15/30
# 15984/15984 [==============================] - 4s 254us/sample - loss: 0.1485 - accuracy: 0.9583
# Epoch 16/30
# 15984/15984 [==============================] - 4s 254us/sample - loss: 0.1412 - accuracy: 0.9596
# Epoch 17/30
# 15984/15984 [==============================] - 4s 255us/sample - loss: 0.1172 - accuracy: 0.9652
# Epoch 18/30
# 15984/15984 [==============================] - 4s 255us/sample - loss: 0.1242 - accuracy: 0.9639
# Epoch 19/30
# 15984/15984 [==============================] - 4s 254us/sample - loss: 0.1218 - accuracy: 0.9653
# Epoch 20/30
# 15984/15984 [==============================] - 4s 255us/sample - loss: 0.0897 - accuracy: 0.9721
# Epoch 21/30
# 15984/15984 [==============================] - 4s 253us/sample - loss: 0.1019 - accuracy: 0.9708
# Epoch 22/30
# 15984/15984 [==============================] - 4s 254us/sample - loss: 0.0925 - accuracy: 0.9724
# Epoch 23/30
# 15984/15984 [==============================] - 4s 254us/sample - loss: 0.1052 - accuracy: 0.9714
# Epoch 24/30
# 15984/15984 [==============================] - 4s 255us/sample - loss: 0.1258 - accuracy: 0.9673
# Epoch 25/30
# 15984/15984 [==============================] - 4s 255us/sample - loss: 0.1001 - accuracy: 0.9717
# Epoch 26/30
# 15984/15984 [==============================] - 4s 256us/sample - loss: 0.0765 - accuracy: 0.9789
# Epoch 27/30
# 15984/15984 [==============================] - 4s 265us/sample - loss: 0.0760 - accuracy: 0.9783
# Epoch 28/30
# 15984/15984 [==============================] - 4s 265us/sample - loss: 0.1070 - accuracy: 0.9727
# Epoch 29/30
# 15984/15984 [==============================] - 4s 259us/sample - loss: 0.0754 - accuracy: 0.9795
# Epoch 30/30
# 15984/15984 [==============================] - 4s 255us/sample - loss: 0.0547 - accuracy: 0.9844

# %%
model.evaluate(x_test,  y_test, verbose=2)
for i in range(10):
    make_plot(x_test, y_test, model)
# Out:
# 10656/10656 - 1s - loss: 0.2963 - accuracy: 0.9595
# actual category:  27
# prediction category:  27
# actual category:  7
# prediction category:  7
# actual category:  28
# prediction category:  28
# actual category:  30
# prediction category:  30
# actual category:  40
# prediction category:  40
# actual category:  10
# prediction category:  10
# actual category:  2
# prediction category:  2
# actual category:  41
# prediction category:  41
# actual category:  7
# prediction category:  7
# actual category:  27
# prediction category:  27
